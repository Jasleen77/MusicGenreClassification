# %%
import cmath
import matplotlib.pyplot as plt
import numpy as np

# %%
def CreateSignal(frequency, time):
    sin = np.sin(2 * np.pi * (frequency * time))
    sin2 = np.sin(2 * np.pi * (2 * frequency * time))
    sin3 = np.sin(2 * np.pi * (3 * frequency * time))

    return sin + sin2 + sin3

# %%
def calculate_centre_of_gravity(mult_signal):
    x_centre = np.mean([x.real for x in mult_signal])
    y_centre = np.mean([x.imag for x in mult_signal])
    return x_centre, y_centre

# %%
def calculate_sum(mult_signal):
    x_sum = np.sum([x.real for x in mult_signal])
    y_sum = np.sum([x.imag for x in mult_signal])
    return x_sum, y_sum

# %%
def create_pure_tone(frequency, time):
    angle = -2 * np.pi * frequency * time
    return np.cos(angle) + 1j * np.sin(angle)

# %%
def plot_fourier_transform(pure_tone_frequency, 
                           signal_frequency, 
                           time, 
                           plot_centre_of_gravity=False,
                           plot_sum=False):
    
    # create sinusoid and signal
    pure_tone = create_pure_tone(pure_tone_frequency, time)
    signal = CreateSignal(signal_frequency, time)
    
    # multiply pure tone and signal
    mult_signal = pure_tone * signal
    
    X = [x.real for x in mult_signal]
    Y = [x.imag for x in mult_signal]

    plt.figure(figsize=(7, 7))
    plt.plot(X, Y, 'o')

    # calculate and plot centre of gravity
    if plot_centre_of_gravity:
        centre_of_gravity = calculate_centre_of_gravity(mult_signal)
        plt.plot([centre_of_gravity[0]], [centre_of_gravity[1]], marker='o', markersize=10, color="red")


    # calculate and plot sum 
    if plot_sum:
        integral = calculate_sum(mult_signal)
        plt.plot([integral[0]], [integral[1]], marker='o', markersize=10, color="green")

    
    # set origin axes
    ax = plt.gca()
    ax.grid(True)
    ax.spines['left'].set_position('zero')
    ax.spines['right'].set_color('none')
    ax.spines['bottom'].set_position('zero')
    ax.spines['top'].set_color('none')

    if not plot_sum:
        plt.xlim(-3, 3)
        plt.ylim(-3, 3)

    plt.show()

# %%
def plot_signal(signal, time):
    plt.figure(figsize=(11, 7))
    plt.plot(signal, time)
    plt.xlabel("Time")
    plt.ylabel("Intensity")
    plt.show()

# %%
time = np.linspace(0, 10, 10000)#Signal between 0 to 10 seconds,with 10000 steps.
signal = CreateSignal(frequency=1, time=time)
plot_signal(time, signal)

# %%
time = np.linspace(0, 1, 10000)#stable
plot_fourier_transform(pure_tone_frequency=1,
                       signal_frequency=1,
                       time=time,
                       plot_centre_of_gravity=True,
                       plot_sum=True)

# %%
time = np.linspace(0, 10, 10000)#complex
plot_fourier_transform(pure_tone_frequency=3.50,
                       signal_frequency=1,
                       time=time,
                       plot_centre_of_gravity=True,
                       plot_sum=True)

# %%
time = np.linspace(0, 10, 10000)#complex
plot_fourier_transform(pure_tone_frequency=7.2,
                       signal_frequency=1,
                       time=time,
                       plot_centre_of_gravity=True,
                       plot_sum=True)

# %%
time = np.linspace(0, 10, 10000)#stable
plot_fourier_transform(pure_tone_frequency=7,
                       signal_frequency=1,
                       time=time,
                       plot_centre_of_gravity=True,
                       plot_sum=False)

# %%
time = np.linspace(0, 10, 10000)#Complex
plot_fourier_transform(pure_tone_frequency=0.34,
                       signal_frequency=1,
                       time=time,
                       plot_centre_of_gravity=True,
                       plot_sum=True)

# %%
time = np.linspace(0, 10, 10000)#stable
plot_fourier_transform(pure_tone_frequency=91,
                       signal_frequency=1,
                       time=time,
                       plot_centre_of_gravity=True,
                       plot_sum=True)

# %%
time = np.linspace(0, 10, 10000)#stable
plot_fourier_transform(pure_tone_frequency=20,
                       signal_frequency=1,
                       time=time,
                       plot_centre_of_gravity=True,
                       plot_sum=True)

# %%
time = np.linspace(0, 10, 10000)#Complex
plot_fourier_transform(pure_tone_frequency=3.7,
                       signal_frequency=1,
                       time=time,
                       plot_centre_of_gravity=True,
                       plot_sum=False)

# %%
time = np.linspace(0, 10, 10000)#Complex
plot_fourier_transform(pure_tone_frequency=100.5,
                       signal_frequency=1,
                       time=time,
                       plot_centre_of_gravity=True,
                       plot_sum=True)

# %%
time = np.linspace(0, 10, 10000)#complex
plot_fourier_transform(pure_tone_frequency=3,
                       signal_frequency=1,
                       time=time,
                       plot_centre_of_gravity=True,
                       plot_sum=True)

# %%
time = np.linspace(0, 10, 15)#complex
plot_fourier_transform(pure_tone_frequency=3.7,
                       signal_frequency=1,
                       time=time,
                       plot_centre_of_gravity=True,
                       plot_sum=True)

# %%
time = np.linspace(0, 10, 100)#complex
plot_fourier_transform(pure_tone_frequency=3.7,
                       signal_frequency=1,
                       time=time,
                       plot_centre_of_gravity=True,
                       plot_sum=True)

# %%
time = np.linspace(0, 10, 1000)#complex
plot_fourier_transform(pure_tone_frequency=3.7,
                       signal_frequency=1,
                       time=time,
                       plot_centre_of_gravity=True,
                       plot_sum=True)

# %% [markdown]
# ## Superimposing pure tones

# %%
 
f = 1
t = np.linspace(0, 10, 10000)

sin = np.sin(2*np.pi * (f * t))
sin2 = np.sin(2*np.pi * (2*f * t))
sin3 = np.sin(2*np.pi * (3*f * t))

sum_signal = sin + sin2 + sin3

plt.figure(figsize=(10, 7))

plt.subplot(4, 1, 1)
plt.plot(t, sum_signal, color="r")

plt.subplot(4, 1, 2)
plt.plot(t, sin)

plt.subplot(4, 1, 3)
plt.plot(t, sin2)

plt.subplot(4, 1, 4)
plt.plot(t, sin3)

plt.show()
